# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'D:\Game_theory_and_Optimization\Analyze game data\soccer-0.csv')
print (df)
type(df)
# Out:
#                                     agent0_grad_norms  agent0_avg_rets  \
# 0   [6.402460098266602, 1.0828007459640503, 25.253...        18.787879
# 1   [4.864669322967529, 0.9070421457290649, 21.886...        17.133956
# 2   [4.463164329528809, 0.7842179536819458, 16.803...        10.315186
# 3   [3.3705976009368896, 0.6927217841148376, 14.05...        11.882510
# 4   [2.4116427898406982, 0.5523935556411743, 9.535...         4.551365
# 5   [1.9623596668243408, 0.34763625264167786, 7.21...         3.262092
# 6   [2.1669187545776367, 0.45095571875572205, 9.22...         0.346021
# 7   [2.653884172439575, 0.42785099148750305, 9.525...         3.991370
# 8   [1.4797945022583008, 0.40293025970458984, 7.19...         2.310231
# 9   [0.9144044518470764, 0.20421136915683746, 2.26...         3.602484
# 10  [1.6163607835769653, 0.43894270062446594, 7.06...        -1.488498
# 11  [0.8864803910255432, 0.12650007009506226, 3.13...        -0.602410
# ...

# %% [markdown]
# agent0_grad_norms	agent0_avg_rets	agent0_avg_lens	agent0_loss	agent1_grad_norms	agent1_avg_rets	agent1_avg_lens	agent1_loss
# ![image.png](attachment:image.png)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(6, 6))
plt.subplots_adjust(wspace=0.2, hspace=0.5)
df['agent0_avg_rets'].plot(legend = 'Player 0', ax=axes[0])
df['agent1_avg_rets'].plot(legend = 'Player 1', ax=axes[0])
axes[0].set_title("Agent avergage returns");

df['agent0_loss'].plot(legend = 'Player 0', ax=axes[1])
df['agent1_loss'].plot(legend = 'Player 1', ax=axes[1])
axes[1].set_title("Agent avergage loss");

# %%
plt.plot(df['agent0_avg_rets'], df['agent1_avg_rets'],'o')
